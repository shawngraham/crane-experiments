# %% [markdown]
# <a href="https://colab.research.google.com/github/shawngraham/crane-experiments/blob/master/one-shot-classification/facial_similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir data && wget https://github.com/shawngraham/Facial-Similarity-with-Siamese-Networks-in-Pytorch/raw/master/data.zip && unzip data.zip -d data/
# Out:
# --2019-03-19 18:13:32--  https://github.com/shawngraham/Facial-Similarity-with-Siamese-Networks-in-Pytorch/raw/master/data.zip
# Resolving github.com (github.com)... 140.82.118.4, 140.82.118.3
# Connecting to github.com (github.com)|140.82.118.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/shawngraham/Facial-Similarity-with-Siamese-Networks-in-Pytorch/master/data.zip [following]
# --2019-03-19 18:13:32--  https://raw.githubusercontent.com/shawngraham/Facial-Similarity-with-Siamese-Networks-in-Pytorch/master/data.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3805886 (3.6M) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>]   3.63M  --.-KB/s    in 0.05s
#
# 2019-03-19 18:13:33 (72.7 MB/s) - ‘data.zip’ saved [3805886/3805886]
#
# Archive:  data.zip
#    creating: data/data/
#    creating: data/data/faces/
#    creating: data/data/faces/training/
#    creating: data/data/faces/training/s34/
#   inflating: data/data/faces/training/s34/7.pgm
#   inflating: data/data/faces/training/s34/6.pgm
#   inflating: data/data/faces/training/s34/4.pgm
#   inflating: data/data/faces/training/s34/5.pgm
#   inflating: data/data/faces/training/s34/1.pgm
#   inflating: data/data/faces/training/s34/2.pgm
#   inflating: data/data/faces/training/s34/3.pgm
#   inflating: data/data/faces/training/s34/8.pgm
#   inflating: data/data/faces/training/s34/9.pgm
#   inflating: data/data/faces/training/s34/10.pgm
#    creating: data/data/faces/training/s33/
#   inflating: data/data/faces/training/s33/7.pgm
#   inflating: data/data/faces/training/s33/6.pgm
#   inflating: data/data/faces/training/s33/4.pgm
#   inflating: data/data/faces/training/s33/5.pgm
#   inflating: data/data/faces/training/s33/1.pgm
#   inflating: data/data/faces/training/s33/2.pgm
#   inflating: data/data/faces/training/s33/3.pgm
#   inflating: data/data/faces/training/s33/8.pgm
#   inflating: data/data/faces/training/s33/9.pgm
#   inflating: data/data/faces/training/s33/10.pgm
#    creating: data/data/faces/training/s2/
#   inflating: data/data/faces/training/s2/7.pgm
#   inflating: data/data/faces/training/s2/6.pgm
#   inflating: data/data/faces/training/s2/4.pgm
#   inflating: data/data/faces/training/s2/5.pgm
#   inflating: data/data/faces/training/s2/1.pgm
#   inflating: data/data/faces/training/s2/2.pgm
#   inflating: data/data/faces/training/s2/3.pgm
#   inflating: data/data/faces/training/s2/8.pgm
#   inflating: data/data/faces/training/s2/9.pgm
#   inflating: data/data/faces/training/s2/10.pgm
#    creating: data/data/faces/training/s32/
#   inflating: data/data/faces/training/s32/7.pgm
#   inflating: data/data/faces/training/s32/6.pgm
#   inflating: data/data/faces/training/s32/4.pgm
#   inflating: data/data/faces/training/s32/5.pgm
#   inflating: data/data/faces/training/s32/1.pgm
#   inflating: data/data/faces/training/s32/2.pgm
#   inflating: data/data/faces/training/s32/3.pgm
#   inflating: data/data/faces/training/s32/8.pgm
#   inflating: data/data/faces/training/s32/9.pgm
#   inflating: data/data/faces/training/s32/10.pgm
#    creating: data/data/faces/training/s35/
#   inflating: data/data/faces/training/s35/7.pgm
#   inflating: data/data/faces/training/s35/6.pgm
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
class Config():
    training_dir = "data/data/faces/training/"
    testing_dir = "data/data/faces/testing/"
    train_batch_size = 64
    train_number_epochs = 100

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            while True:
                #keep looping till a different class image is found
                
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] !=img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[0.]
#  [0.]
#  [0.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]]

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1, 4, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(4),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(4, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


        )

        self.fc1 = nn.Sequential(
            nn.Linear(8*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# Epoch number 0
#  Current loss 1.935801386833191
#
# Epoch number 1
#  Current loss 3.1395585536956787
#
# Epoch number 2
#  Current loss 1.3745529651641846
#
# Epoch number 3
#  Current loss 1.2083990573883057
#
# Epoch number 4
#  Current loss 1.154298186302185
#
# Epoch number 5
#  Current loss 1.1838518381118774
#
# Epoch number 6
#  Current loss 1.1661748886108398
#
# Epoch number 7
#  Current loss 1.1347521543502808
#
# Epoch number 8
#  Current loss 1.173985242843628
#
# Epoch number 9
#  Current loss 1.2235195636749268
#
# Epoch number 10
#  Current loss 1.1504244804382324
#
# Epoch number 11
#  Current loss 1.1812467575073242
#
# Epoch number 12
#  Current loss 1.1342873573303223
#
# Epoch number 13
#  Current loss 1.1793180704116821
#
# Epoch number 14
#  Current loss 1.129913091659546
#
# Epoch number 15
#  Current loss 1.2228137254714966
#
# Epoch number 16
#  Current loss 1.137070655822754
#
# Epoch number 17
#  Current loss 1.1574792861938477
#
# Epoch number 18
#  Current loss 1.102346420288086
#
# Epoch number 19
#  Current loss 1.154247522354126
#
# Epoch number 20
#  Current loss 1.1585065126419067
#
# Epoch number 21
#  Current loss 1.1419254541397095
#
# Epoch number 22
#  Current loss 1.1206659078598022
#
# Epoch number 23
#  Current loss 1.1833178997039795
#
# Epoch number 24
#  Current loss 1.1429954767227173
#
# Epoch number 25
#  Current loss 1.1098500490188599
#
# Epoch number 26
#  Current loss 1.121309518814087
#
# Epoch number 27
#  Current loss 1.053748369216919
#
# Epoch number 28
#  Current loss 1.0919442176818848
#
# Epoch number 29
#  Current loss 1.1404706239700317
#
# Epoch number 30
#  Current loss 1.2576024532318115
#
# Epoch number 31
#  Current loss 1.2290526628494263
#
# Epoch number 32
#  Current loss 1.1190426349639893
#
# Epoch number 33
#  Current loss 1.1605961322784424
#
# Epoch number 34
#  Current loss 1.160677433013916
#
# Epoch number 35
#  Current loss 1.1349122524261475
#
# Epoch number 36
#  Current loss 1.1140868663787842
#
# Epoch number 37
#  Current loss 1.1572699546813965
#
# Epoch number 38
#  Current loss 1.1342754364013672
#
# Epoch number 39
#  Current loss 1.106410264968872
#
# Epoch number 40
#  Current loss 1.0572798252105713
#
# Epoch number 41
#  Current loss 1.215270757675171
#
# Epoch number 42
#  Current loss 1.1126561164855957
#
# Epoch number 43
#  Current loss 1.1191269159317017
#
# Epoch number 44
#  Current loss 1.1036088466644287
#
# Epoch number 45
#  Current loss 1.0973867177963257
#
# Epoch number 46
#  Current loss 1.158674955368042
#
# Epoch number 47
#  Current loss 1.1432018280029297
#
# Epoch number 48
#  Current loss 1.1072027683258057
#
# Epoch number 49
#  Current loss 1.080732822418213
#
# Epoch number 50
#  Current loss 1.1760377883911133
#
# Epoch number 51
#  Current loss 1.2168850898742676
#
# Epoch number 52
#  Current loss 1.1250849962234497
#
# Epoch number 53
#  Current loss 1.122704029083252
#
# Epoch number 54
#  Current loss 1.128746509552002
#
# Epoch number 55
#  Current loss 1.06923246383667
#
# Epoch number 56
#  Current loss 1.115515947341919
#
# Epoch number 57
#  Current loss 1.1103438138961792
#
# Epoch number 58
#  Current loss 1.109123706817627
#
# Epoch number 59
#  Current loss 1.1670167446136475
#
# Epoch number 60
#  Current loss 1.174309253692627
#
# Epoch number 61
#  Current loss 1.1268093585968018
#
# Epoch number 62
#  Current loss 1.094508409500122
#
# Epoch number 63
#  Current loss 1.2271461486816406
#
# Epoch number 64
#  Current loss 1.1160848140716553
#
# Epoch number 65
#  Current loss 1.1041349172592163
#
# Epoch number 66
#  Current loss 1.0939443111419678
#
# Epoch number 67
#  Current loss 1.1464612483978271
#
# Epoch number 68
#  Current loss 1.1626408100128174
#
# Epoch number 69
#  Current loss 1.1029763221740723
#
# Epoch number 70
#  Current loss 1.1035677194595337
#
# Epoch number 71
#  Current loss 1.1426236629486084
#
# Epoch number 72
#  Current loss 1.1232011318206787
#
# Epoch number 73
#  Current loss 1.0638532638549805
#
# Epoch number 74
#  Current loss 1.0090276002883911
#
# Epoch number 75
#  Current loss 1.1012604236602783
#
# Epoch number 76
#  Current loss 1.1374567747116089
#
# Epoch number 77
#  Current loss 1.1614900827407837
#
# Epoch number 78
#  Current loss 1.1896580457687378
#
# Epoch number 79
#  Current loss 1.148953914642334
#
# Epoch number 80
#  Current loss 1.1109709739685059
#
# Epoch number 81
#  Current loss 1.090721845626831
#
# Epoch number 82
#  Current loss 1.1121506690979004
#
# Epoch number 83
#  Current loss 1.0854865312576294
#
# Epoch number 84
#  Current loss 1.0545587539672852
#
# Epoch number 85
#  Current loss 1.1122723817825317
#
# Epoch number 86
#  Current loss 1.0944349765777588
#
# Epoch number 87
#  Current loss 1.1159782409667969
#
# Epoch number 88
#  Current loss 1.197188138961792
#
# Epoch number 89
#  Current loss 1.1278902292251587
#
# Epoch number 90
#  Current loss 1.0817956924438477
#
# Epoch number 91
#  Current loss 1.245437502861023
#
# Epoch number 92
#  Current loss 1.1573960781097412
#
# Epoch number 93
#  Current loss 1.1470643281936646
#
# Epoch number 94
#  Current loss 1.0926326513290405
#
# Epoch number 95
#  Current loss 1.1135584115982056
#
# Epoch number 96
#  Current loss 1.0974079370498657
#
# Epoch number 97
#  Current loss 1.2037913799285889
#
# Epoch number 98
#  Current loss 1.0986496210098267
#
# Epoch number 99
#  Current loss 1.1601996421813965

# %%
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))
